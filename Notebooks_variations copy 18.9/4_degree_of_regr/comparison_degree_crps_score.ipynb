# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent.parent))

import mesmer
import model
import model_analysis

import importlib
import matplotlib.pyplot as plt
import xarray as xr

import numpy as np
from scipy.stats import skewnorm

import cartopy.crs as ccrs

# %%
is_local_data = False
Month_idx = 4
safe = False
start = None
end = None
max_depth = 3

# %% [markdown]
# ### Load parameters of the transformations

# %%
mean_keys =["mean_1","mean_2","kontrolle"] 
var_keys = ["var_1","var_2"]

# %%
parameter_sets = {}
for mean_key in mean_keys:
    if mean_key == "kontrolle":
        parameter_sets["kontrolle"] = model.loading.load_params(var = "mrsol",scen= "historical", folder = f"MPI-ESM1-2-LR/variations/mean_var_regr_degree/kontrolle/local{is_local_data}/month{Month_idx}", name=f"start={start},end={end}.max_depth{max_depth}")
        continue
    for var_key in var_keys:
        parameter_sets[f"{mean_key}_{var_key}"] = model.loading.load_params(var = "mrsol",scen= "historical", folder = f"MPI-ESM1-2-LR/variations/mean_var_regr_degree/{mean_key}_{var_key}/local{is_local_data}/month{Month_idx}", name=f"start={start},end={end}.max_depth{max_depth}")

# %%
#parameter_sets["kontrolle"]

# %% [markdown]
# the mask should only change if one is based on relative data, and one is abs because the threshold has a diffrent effect

# %%
for para_key,para in parameter_sets.items():
    print(parameter_sets["mean_1_var_1"]["detail_mask"].equals(para["detail_mask"]))

chunk_mask = parameter_sets["mean_1_var_1"]["chunk_mask"]
# Out:
# True
# True
# True
# True
# True

# %%
for para_key,para in parameter_sets.items():
    print(parameter_sets["mean_1_var_1"]["chunk_mask"].equals(para["chunk_mask"]))

detal_mask = parameter_sets["mean_1_var_1"]["detail_mask"]
# Out:
# True
# True
# True
# True
# True

# %%
for para_key,para in parameter_sets.items():
    print(parameter_sets["mean_1_var_1"]["local_maximas"].equals(para["local_maximas"]))

max = model.mask.mask_mask(parameter_sets["mean_1_var_1"]["local_maximas"],parameter_sets["mean_1_var_1"]["chunk_mask"].mrsol).isel(depth=slice(0, max_depth))
maximas = mesmer.grid.stack_lat_lon(max).drop_vars("depth_bnds").transpose("gridcell","depth").mrsol
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# ### Load test input and target

# %%
run_idx = 4
raw_mrsol_for_test = model.loading.load_data_set(var = "mrsol", local = is_local_data, run_idx=run_idx)

tas_ds = model.loading.load_data_set(var = "tas", local = is_local_data, run_idx=run_idx)
pr_ds = model.loading.load_data_set(var = "pr", local = is_local_data, run_idx=run_idx)
tas_ds = model.shape_data.prune_group_ds_timespan(tas_ds,Month_idx=Month_idx)
pr_ds = model.shape_data.prune_group_ds_timespan(pr_ds,Month_idx=Month_idx)

raw_input_for_test = xr.merge([tas_ds,pr_ds]).drop_vars("file_qf")

# %% [markdown]
# ### shape inputs

# %%
def shape_input(ds, chunk_mask):
    ds = ds.sel(time=slice(start, end)).resample(time="ME").mean()
    ds = ds.sel(time= ds.time.dt.month == Month_idx)
    ds = model.mask.mask_mask(ds,chunk_mask)
    ds = mesmer.grid.stack_lat_lon(ds)
    return ds

# %%
input = shape_input(raw_input_for_test, chunk_mask.mrsol)

# %% [markdown]
# ### shape targets

# %%
def shape_target(ds):
    #ds = ds.clip(min = 1e-32)
    ds = ds.sel(time=slice(start, end)).resample(time="ME").mean()
    ds = ds.sel(time= ds.time.dt.month == Month_idx).isel(depth=slice(0, max_depth)).drop_vars("depth_bnds")
    return ds

# %%
def mask_stack_target(ds):
    masked_ds, chunk_mask, detail_mask= model.mask.mask_nonpositiv_height_chunks(ds)
    ds = mesmer.grid.stack_lat_lon(masked_ds)
    ds = ds.transpose("gridcell","time", "depth")
    return ds

# %%
target_unstacked = shape_target(raw_mrsol_for_test)
target = mask_stack_target(target_unstacked)

# %% [markdown]
# glaub unnötig
# rel transform
# maximas = parameter_sets["rel_transform"]["local_maximas"]
# rel_target = raw_mrsol_for_test/maximas
# rel_target = shape_target(rel_target)
# targets["rel"] = mask_stack_target(rel_target)
#
# Log transform
# log_target = shape_target(raw_mrsol_for_test)
# log_target = mask_stack_target(log_target)
# targets["log"] = model.transform.Log_Transform_ds(log_target)
# Logit transform
# maximas = parameter_sets["logit_transform"]["local_maximas"]
# logit_target = raw_mrsol_for_test/maximas
# logit_target = shape_target(logit_target)
# logit_target = mask_stack_target(logit_target)
# targets["logit"] = model.transform.Logit_Transform_ds(logit_target)

# %% [markdown]
# ### Emulate

# %%
predictions = {}

# %%
for mean_degree, mean_key in enumerate(mean_keys, start=1):
    if mean_key == "kontrolle":
        #mean Prediction
        LinReg_mean = model.stats._parallel_linear_regression.ParLinearRegression()
        LinReg_mean = LinReg_mean.from_params(parameter_sets["kontrolle"]["mean"])
        predictions["kontrolle"] = {}
        predictions["kontrolle"]["mean"] = LinReg_mean.predict(input).transpose("gridcell","time", "depth")

        #var Prediction
        LinReg_var = model.stats._parallel_linear_regression.ParLinearRegression()
        LinReg_var = LinReg_var.from_params(parameter_sets["kontrolle"]["variance"])
        predictions["kontrolle"]["variance"] = LinReg_var.predict(input).transpose("gridcell","time", "depth")
        continue
    for var_degree, var_key in enumerate(var_keys, start=1):
        #mean Prediction
        PolReg_mean = model.stats._parallel_polynomial_regression.ParPolyRegression(degree=mean_degree)
        PolReg_mean = PolReg_mean.from_params(parameter_sets[f"{mean_key}_{var_key}"]["mean"])
        predictions[f"{mean_key}_{var_key}"] = {}
        predictions[f"{mean_key}_{var_key}"]["mean"] = PolReg_mean.predict(input,location_dim="gridcell",regr_dim="time").transpose("gridcell","time", "depth")

        #var Prediction
        PolReg_var = model.stats._parallel_polynomial_regression.ParPolyRegression(degree=var_degree)
        PolReg_var = PolReg_var.from_params(parameter_sets[f"{mean_key}_{var_key}"]["variance"])
        predictions[f"{mean_key}_{var_key}"]["variance"] = PolReg_var.predict(input,location_dim="gridcell", regr_dim="time").transpose("gridcell","time", "depth")
# Out:
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Dec 19 16:55:09 2019: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/664bf0d5-5ae5-48aa-bb2a-f71acf46386c
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/tas/MPI-...
#     original_file_hash_codes:  1f97bc429d1731b47b6a0c3b1e5945fbd188e5e87b56be...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...
# {'pr', 'tas'}
# {'pr', 'tas'}
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# <xarray.Dataset> Size: 258kB
# Dimensions:        (gridcell: 2935, depth: 3)
# Coordinates:
#     lat            (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25
#     lon            (gridcell) float64 23kB 288.8 291.2 293.8 ... 296.2 298.8
#   * depth          (depth) float64 24B 0.03 0.19 0.78
# Dimensions without coordinates: gridcell
# Data variables:
#     intercept      (gridcell, depth) float64 70kB 1.248 1.08 ... 0.5846 1.307
#     tas            (gridcell, depth) float64 70kB 0.0008301 ... -0.001379
#     pr             (gridcell, depth) float64 70kB 7.991e+03 335.7 ... 1.794e+03
#     fit_intercept  bool 1B True
# Attributes:
#     degree:         1
#     n_features_in:  2
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Dec 19 16:55:09 2019: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/664bf0d5-5ae5-48aa-bb2a-f71acf46386c
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/tas/MPI-...
#     original_file_hash_codes:  1f97bc429d1731b47b6a0c3b1e5945fbd188e5e87b56be...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...
# {'pr', 'tas'}
# {'pr', 'tas'}
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# <xarray.Dataset> Size: 258kB
# Dimensions:        (gridcell: 2935, depth: 3)
# Coordinates:
#     lat            (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25
#     lon            (gridcell) float64 23kB 288.8 291.2 293.8 ... 296.2 298.8
#   * depth          (depth) float64 24B 0.03 0.19 0.78
# Dimensions without coordinates: gridcell
# Data variables:
#     intercept      (gridcell, depth) float64 70kB 3.463 0.2397 ... 0.003865
#     tas            (gridcell, depth) float64 70kB -0.01223 ... 0.0001419
#     pr             (gridcell, depth) float64 70kB -589.0 -131.0 ... -2.497e+03
#     fit_intercept  bool 1B True
# Attributes:
#     degree:         1
#     n_features_in:  2
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Dec 19 16:55:09 2019: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/664bf0d5-5ae5-48aa-bb2a-f71acf46386c
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/tas/MPI-...
#     original_file_hash_codes:  1f97bc429d1731b47b6a0c3b1e5945fbd188e5e87b56be...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...
# {'pr', 'tas'}
# {'pr', 'tas'}
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# <xarray.Dataset> Size: 258kB
# Dimensions:        (gridcell: 2935, depth: 3)
# Coordinates:
#     lat            (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25
#     lon            (gridcell) float64 23kB 288.8 291.2 293.8 ... 296.2 298.8
#   * depth          (depth) float64 24B 0.03 0.19 0.78
# Dimensions without coordinates: gridcell
# Data variables:
#     intercept      (gridcell, depth) float64 70kB 1.248 1.08 ... 0.5846 1.307
#     tas            (gridcell, depth) float64 70kB 0.0008301 ... -0.001379
#     pr             (gridcell, depth) float64 70kB 7.991e+03 335.7 ... 1.794e+03
#     fit_intercept  bool 1B True
# Attributes:
#     degree:         1
#     n_features_in:  2
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Dec 19 16:55:09 2019: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/664bf0d5-5ae5-48aa-bb2a-f71acf46386c
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/tas/MPI-...
#     original_file_hash_codes:  1f97bc429d1731b47b6a0c3b1e5945fbd188e5e87b56be...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...
# {'tas pr', 'tas^2', 'pr^2', 'pr', 'tas'}
# {'tas pr', 'tas^2', 'pr^2', 'pr', 'tas'}
# <xarray.Dataset> Size: 19MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
#     tas^2    (time, gridcell) float64 4MB 7.744e+04 7.715e+04 ... 6.191e+04
#     tas pr   (time, gridcell) float64 4MB 0.01396 0.01074 ... 0.0008607
#     pr^2     (time, gridcell) float64 4MB 2.516e-09 1.495e-09 ... 1.197e-11
# <xarray.Dataset> Size: 470kB
# Dimensions:        (gridcell: 2935, depth: 3)
# Coordinates:
#     lat            (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25
#     lon            (gridcell) float64 23kB 288.8 291.2 293.8 ... 296.2 298.8
#   * depth          (depth) float64 24B 0.03 0.19 0.78
# Dimensions without coordinates: gridcell
# Data variables:
#     intercept      (gridcell, depth) float64 70kB 1.324e+03 16.03 ... -8.809
#     tas            (gridcell, depth) float64 70kB -9.493 -0.1059 ... 0.07045
#     pr             (gridcell, depth) float64 70kB -7.551e+04 ... 7.036e+04
#     tas^2          (gridcell, depth) float64 70kB 0.01702 ... -0.0001402
#     tas pr         (gridcell, depth) float64 70kB 264.7 161.1 ... -86.4 -294.0
#     pr^2           (gridcell, depth) float64 70kB 1.288e+07 7.133e+06 ... -5.928
#     fit_intercept  bool 1B True
# Attributes:
#     degree:         2
#     n_features_in:  2
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Dec 19 16:55:09 2019: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/664bf0d5-5ae5-48aa-bb2a-f71acf46386c
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/tas/MPI-...
#     original_file_hash_codes:  1f97bc429d1731b47b6a0c3b1e5945fbd188e5e87b56be...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...
# {'tas pr', 'tas^2', 'pr^2', 'pr', 'tas'}
# {'tas pr', 'tas^2', 'pr^2', 'pr', 'tas'}
# <xarray.Dataset> Size: 19MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
#     tas^2    (time, gridcell) float64 4MB 7.744e+04 7.715e+04 ... 6.191e+04
#     tas pr   (time, gridcell) float64 4MB 0.01396 0.01074 ... 0.0008607
#     pr^2     (time, gridcell) float64 4MB 2.516e-09 1.495e-09 ... 1.197e-11
# <xarray.Dataset> Size: 470kB
# Dimensions:        (gridcell: 2935, depth: 3)
# Coordinates:
#     lat            (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25
#     lon            (gridcell) float64 23kB 288.8 291.2 293.8 ... 296.2 298.8
#   * depth          (depth) float64 24B 0.03 0.19 0.78
# Dimensions without coordinates: gridcell
# Data variables:
#     intercept      (gridcell, depth) float64 70kB 131.7 -338.4 ... -66.83 -171.9
#     tas            (gridcell, depth) float64 70kB -1.074 2.418 ... 0.541 1.39
#     pr             (gridcell, depth) float64 70kB 7.394e+05 ... 5.095e+05
#     tas^2          (gridcell, depth) float64 70kB 0.002173 ... -0.002793
#     tas pr         (gridcell, depth) float64 70kB -2.566e+03 ... -2.045e+03
#     pr^2           (gridcell, depth) float64 70kB -1.577e+08 ... -99.88
#     fit_intercept  bool 1B True
# Attributes:
#     degree:         2
#     n_features_in:  2
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Dec 19 16:55:09 2019: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/664bf0d5-5ae5-48aa-bb2a-f71acf46386c
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/tas/MPI-...
#     original_file_hash_codes:  1f97bc429d1731b47b6a0c3b1e5945fbd188e5e87b56be...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...
# {'pr', 'tas'}
# {'pr', 'tas'}
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# <xarray.Dataset> Size: 258kB
# Dimensions:        (gridcell: 2935, depth: 3)
# Coordinates:
#     lat            (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25
#     lon            (gridcell) float64 23kB 288.8 291.2 293.8 ... 296.2 298.8
#   * depth          (depth) float64 24B 0.03 0.19 0.78
# Dimensions without coordinates: gridcell
# Data variables:
#     intercept      (gridcell, depth) float64 70kB 3.105 0.1819 ... -0.1467
#     tas            (gridcell, depth) float64 70kB -0.01098 ... 0.0007586
#     pr             (gridcell, depth) float64 70kB -392.6 -97.7 ... -2.968e+03
#     fit_intercept  bool 1B True
# Attributes:
#     degree:         1
#     n_features_in:  2
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Dec 19 16:55:09 2019: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/664bf0d5-5ae5-48aa-bb2a-f71acf46386c
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/tas/MPI-...
#     original_file_hash_codes:  1f97bc429d1731b47b6a0c3b1e5945fbd188e5e87b56be...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...
# {'tas pr', 'tas^2', 'pr^2', 'pr', 'tas'}
# {'tas pr', 'tas^2', 'pr^2', 'pr', 'tas'}
# <xarray.Dataset> Size: 19MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
#     tas^2    (time, gridcell) float64 4MB 7.744e+04 7.715e+04 ... 6.191e+04
#     tas pr   (time, gridcell) float64 4MB 0.01396 0.01074 ... 0.0008607
#     pr^2     (time, gridcell) float64 4MB 2.516e-09 1.495e-09 ... 1.197e-11
# <xarray.Dataset> Size: 470kB
# Dimensions:        (gridcell: 2935, depth: 3)
# Coordinates:
#     lat            (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25
#     lon            (gridcell) float64 23kB 288.8 291.2 293.8 ... 296.2 298.8
#   * depth          (depth) float64 24B 0.03 0.19 0.78
# Dimensions without coordinates: gridcell
# Data variables:
#     intercept      (gridcell, depth) float64 70kB 131.7 -338.4 ... -66.83 -171.9
#     tas            (gridcell, depth) float64 70kB -1.074 2.418 ... 0.541 1.39
#     pr             (gridcell, depth) float64 70kB 7.394e+05 ... 5.095e+05
#     tas^2          (gridcell, depth) float64 70kB 0.002173 ... -0.002793
#     tas pr         (gridcell, depth) float64 70kB -2.566e+03 ... -2.045e+03
#     pr^2           (gridcell, depth) float64 70kB -1.577e+08 ... -99.88
#     fit_intercept  bool 1B True
# Attributes:
#     degree:         2
#     n_features_in:  2
# <xarray.Dataset> Size: 8MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Dec 19 16:55:09 2019: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/664bf0d5-5ae5-48aa-bb2a-f71acf46386c
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/tas/MPI-...
#     original_file_hash_codes:  1f97bc429d1731b47b6a0c3b1e5945fbd188e5e87b56be...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...
# {'tas pr', 'tas^2', 'pr^2', 'pr', 'tas'}
# {'tas pr', 'tas^2', 'pr^2', 'pr', 'tas'}
# <xarray.Dataset> Size: 19MB
# Dimensions:  (time: 165, gridcell: 2935)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1850-04-30 1851-04-30 ... 2014-04-30
#     lat      (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25 81.25
#     lon      (gridcell) float64 23kB 288.8 291.2 293.8 ... 293.8 296.2 298.8
#     height   float64 8B 2.0
# Dimensions without coordinates: gridcell
# Data variables:
#     tas      (time, gridcell) float64 4MB 278.3 277.8 277.8 ... 248.2 248.8
#     pr       (time, gridcell) float64 4MB 5.016e-05 3.866e-05 ... 3.459e-06
#     tas^2    (time, gridcell) float64 4MB 7.744e+04 7.715e+04 ... 6.191e+04
#     tas pr   (time, gridcell) float64 4MB 0.01396 0.01074 ... 0.0008607
#     pr^2     (time, gridcell) float64 4MB 2.516e-09 1.495e-09 ... 1.197e-11
# <xarray.Dataset> Size: 470kB
# Dimensions:        (gridcell: 2935, depth: 3)
# Coordinates:
#     lat            (gridcell) float64 23kB -56.25 -56.25 -56.25 ... 81.25 81.25
#     lon            (gridcell) float64 23kB 288.8 291.2 293.8 ... 296.2 298.8
#   * depth          (depth) float64 24B 0.03 0.19 0.78
# Dimensions without coordinates: gridcell
# Data variables:
#     intercept      (gridcell, depth) float64 70kB 1.471e+03 16.21 ... 9.057
#     tas            (gridcell, depth) float64 70kB -10.59 -0.1098 ... -0.07478
#     pr             (gridcell, depth) float64 70kB 8.304e+04 ... 1.056e+05
#     tas^2          (gridcell, depth) float64 70kB 0.01904 0.0001856 ... 0.000155
#     tas pr         (gridcell, depth) float64 70kB -295.6 114.6 ... -98.97 -437.4
#     pr^2           (gridcell, depth) float64 70kB -9.876e+06 ... -8.894
#     fit_intercept  bool 1B True
# Attributes:
#     degree:         2
#     n_features_in:  2

# %% [markdown]
# #### Scores

# %%
score_sets = {}

# %%
score_keys = parameter_sets.keys()
score_keys
# Out:
# dict_keys(['mean_1_var_1', 'mean_1_var_2', 'mean_2_var_1', 'mean_2_var_2', 'kontrolle'])

# %%
predictions.keys()
predictions["mean_1_var_1"].keys()
# Out:
# dict_keys(['mean', 'variance'])

# %%
for key in score_keys:
    score_sets[key] = model_analysis.crps_score.crps_norm_score(predictions[key]["mean"],predictions[key]["variance"], target, transformation = "Logit", maximas_da = maximas,ensemble_size = 15)

# %%
for s_keys, scores in score_sets.items():
    score_sets[s_keys] = mesmer.grid.unstack_lat_lon_and_align(scores, target_unstacked)
    
    score_sets[s_keys] = model.mask.mask_mask(score_sets[s_keys],detal_mask.mrsol,"lon", "lat", "depth")

# %%
all_scores_ds =xr.Dataset({key : score.crps_score for key, score in score_sets.items()})

# %%
all_scores_ds.mean(dim=["lon","lat","time"])
# Out:
# <xarray.Dataset> Size: 144B
# Dimensions:       (depth: 3)
# Coordinates:
#   * depth         (depth) float64 24B 0.03 0.19 0.78
# Data variables:
#     mean_1_var_1  (depth) float64 24B 0.418 1.642 6.729
#     mean_1_var_2  (depth) float64 24B 0.4177 1.645 6.732
#     mean_2_var_1  (depth) float64 24B 0.4078 1.634 6.739
#     mean_2_var_2  (depth) float64 24B 0.4083 1.637 6.75
#     kontrolle     (depth) float64 24B 0.4178 1.643 6.723

# %%
fig_global_crpss, ax = plt.subplots(
    subplot_kw={"projection": ccrs.PlateCarree()},
    nrows=len(score_keys),
    ncols=1,
    figsize=(8, 4 * len(score_keys))
)
depth = 0

for i, s_key in enumerate(score_keys):
    da = all_scores_ds.isel(depth=depth).mean("time")[s_key]
    da.plot(ax=ax[i])
    ax[i].coastlines()
    ax[i].set_title(s_key)

# %%
depth = 1

choice = "mean_2_var_1"

for i, s_key in enumerate(score_keys):
    if s_key == choice:
        continue
    vs = model_analysis.crps_score.combine_two_crps_and_the_crpss(score_sets[choice].crps_score,score_sets[s_key].crps_score,choice,s_key)

    fig_global_crpss, ax = plt.subplots(
    subplot_kw={"projection": ccrs.PlateCarree()},
    nrows=2,
    ncols=1,
    figsize=(8, 8)
    )
    """
    da = vs.isel(depth=depth).mean("time")[s_key]
    da.plot(ax=ax[0])
    ax[0].coastlines()
    ax[0].set_title(s_key)

    da = vs.isel(depth=depth).mean("time")[choice]
    da.plot(ax=ax[1])
    ax[1].coastlines()
    ax[1].set_title(choice)
    """
    da = vs.isel(depth=depth)[f"crpss_{s_key}_vs_{choice}"].clip(min=-1)
    da.plot(ax=ax[0])
    ax[0].coastlines()
    ax[0].set_title(f"crpss_score {s_key} against {choice}")

    da = vs.isel(depth=depth)[f"crpss_{choice}_vs_{s_key}"].clip(min=-1)
    da.plot(ax=ax[1])
    ax[1].coastlines()
    ax[1].set_title(f"crpss_score {choice} against {s_key}")

    fig_global_crpss.show()
