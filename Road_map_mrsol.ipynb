# %% [markdown]
# ### import

# %%
import pathlib
from pathlib import Path

#import cartopy.crs as ccrs
#import filefisher

import importlib
import matplotlib.pyplot as plt
import calendar
import numpy as np
import xarray as xr
import pandas as pd
from xarray import DataTree
import math


import warnings
import Play
import sklearn
from scipy.stats import (
    norm,
    gamma,
    beta,
    expon,
    weibull_min,
    lognorm,
    uniform,
    t,
    pareto
)

#from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression


xr.set_options(keep_attrs=True, display_expand_data=False)
np.set_printoptions(threshold=100, edgeitems=10)

# %%
#Update Module
importlib.reload(Play.plot_one_var)
#importlib.reload(Play.manuel_forest_tests)
importlib.reload(Play.forest_building)
importlib.reload(Play.forest_analise)
importlib.reload(Play.shape_data)
importlib.reload(Play.plot_helper_dependence)
importlib.reload(Play.LinReg_analise)
importlib.reload(Play.LinReg_building)
importlib.reload(Play.plot_helper_compare_forest_linreg)
importlib.reload(Play.plot_residuals_scatter)
importlib.reload(Play.distribution_analise)
importlib.reload(Play.distribution_building)
# Out:
# <module 'Play.distribution_building' from '/home/pjunghans/BachelorArbeit/Play/distribution_building.py'>

# %% [markdown]
# ### Transformation of mrsol

# %%
Play.distribution_analise.all_histograms_vs_mixed_densities(scenarios=["historical"],variables=["mrsol"], lat_idx=17, lon_idx = 33, depth_arr=[0,1],location = "southamerica/transform", save = True, all = True, Transform=True)
# Out:
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:361: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,0, np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
#   mixed_pdf = np.mean([norm.pdf(x_pdf,est_values[i], np.sqrt(var_regr.predict(input_values))[i]) for i in range(len(input_values))], axis = 0)   #lineare variance schätzung kann unter 0 gehen
# /home/pjunghans/BachelorArbeit/Play/distribution_analise.py:348: RuntimeWarning: invalid value encountered in sqrt
# ...
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay

# %%
ds = Play.shape_data.show_data_set(var = "mrsol")

# %%
ds_hurs = xr.load_dataset(Path('/net/atmos/data/cmip6-ng/hurs/ann/g025/hurs_ann_MPI-ESM1-2-LR_historical_r50i1p1f1_g025.nc'))
ds_hurs
# Out:
# <xarray.Dataset> Size: 14MB
# Dimensions:    (time: 165, bnds: 2, lat: 72, lon: 144)
# Coordinates:
#   * time       (time) datetime64[ns] 1kB 1850-07-01T06:00:00 ... 2014-07-01T0...
#   * lat        (lat) float64 576B -88.75 -86.25 -83.75 ... 83.75 86.25 88.75
#   * lon        (lon) float64 1kB 1.25 3.75 6.25 8.75 ... 351.2 353.8 356.2 358.8
#     height     float64 8B 2.0
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] 3kB 1850-01-16T12:00:00 ... 2014-1...
#     hurs       (time, lat, lon) float64 14MB 95.73 95.74 95.74 ... 102.7 102.7
#     file_qf    float64 8B 0.0
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Thu Jan 11 04:37:17 2024: cdo -O -b F64 -remap...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.6.0
#     tracking_id:               hdl:21.14100/9558abd1-26b1-495e-a0a4-3b847f4290c5
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Amon/hurs/MPI...
#     original_file_hash_codes:  b27a9b47115094ed503f16b4b469449617686ce5cb43ae...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...

# %%
ds
# Out:
# <xarray.Dataset> Size: 127MB
# Dimensions:     (depth: 5, bnds: 2, time: 1980, lat: 40, lon: 40)
# Coordinates:
#   * depth       (depth) float64 40B 0.03 0.19 0.78 2.68 6.98
#   * time        (time) datetime64[ns] 16kB 1850-01-16T12:00:00 ... 2014-12-16...
#   * lat         (lat) float64 320B -87.75 -83.25 -78.75 ... 78.75 83.25 87.75
#   * lon         (lon) float64 320B 0.0 9.0 18.0 27.0 ... 324.0 333.0 342.0 351.0
# Dimensions without coordinates: bnds
# Data variables:
#     depth_bnds  (depth, bnds) float64 80B 0.0 0.065 0.065 ... 4.134 4.134 9.834
#     mrsol       (time, depth, lat, lon) float64 127MB 0.0 0.0 0.0 ... nan nan
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Wed Jul 15 10:14:02 2026: cdo remapbil,r40x40 ...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/0fd5d006-722a-4650-a835-398b6aae92c9
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Emon/mrsol/MP...
#     original_file_hash_codes:  35dde960416cda436bd90358a67f602de138e51219997c...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...

# %%
ds.isel(depth = 0).mrsol.isel(time = 0).plot(x="lon");

# %%
ds_hurs.hurs.mean(dim="time").plot(x="lon");

# %%
np.min(ds_hurs.hurs)
# Out:
# <xarray.DataArray 'hurs' ()> Size: 8B
# 11.7
# Coordinates:
#     height   float64 8B 2.0
# Attributes:
#     standard_name:   relative_humidity
#     long_name:       Near-Surface Relative Humidity
#     units:           %
#     comment:         The relative humidity with respect to liquid water for T...
#     original_units:  1
#     history:         2023-03-21T18:30:21Z altered by CMOR: Converted units fr...
#     cell_methods:    area: time: mean
#     cell_measures:   area: areacella

# %%
ds.isel(depth = 0).mrsol.isel(time = 0).plot(x="lon");

# %%
ds_T = ds
ds_T["mrsol"] = (ds.mrsol/100)    
ds_T["mrsol"] = np.log(ds_T.mrsol/(1-ds_T.mrsol))
# Out:
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
ds_T.isel(depth = 0).mrsol.isel(time = 0).plot(x="lon");

# %%
ds_T
# Out:
# <xarray.Dataset> Size: 127MB
# Dimensions:     (depth: 5, bnds: 2, time: 1980, lat: 40, lon: 40)
# Coordinates:
#   * depth       (depth) float64 40B 0.03 0.19 0.78 2.68 6.98
#   * time        (time) datetime64[ns] 16kB 1850-01-16T12:00:00 ... 2014-12-16...
#   * lat         (lat) float64 320B -87.75 -83.25 -78.75 ... 78.75 83.25 87.75
#   * lon         (lon) float64 320B 0.0 9.0 18.0 27.0 ... 324.0 333.0 342.0 351.0
# Dimensions without coordinates: bnds
# Data variables:
#     depth_bnds  (depth, bnds) float64 80B 0.0 0.065 0.065 ... 4.134 4.134 9.834
#     mrsol       (time, depth, lat, lon) float64 127MB -inf -inf -inf ... nan nan
# Attributes: (12/52)
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     history:                   Wed Jul 15 10:14:02 2026: cdo remapbil,r40x40 ...
#     source:                    MPI-ESM1.2-LR (2017): \naerosol: none, prescri...
#     institution:               Max Planck Institute for Meteorology
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     ...                        ...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/0fd5d006-722a-4650-a835-398b6aae92c9
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
#     original_file_names:       /net/atmos/data/cmip6/historical/Emon/mrsol/MP...
#     original_file_hash_codes:  35dde960416cda436bd90358a67f602de138e51219997c...
#     CDO:                       Climate Data Operators version 1.9.6 (http://m...

# %%
ds_T.mrsol.where(np.isfinite(ds_T.mrsol)).min(skipna=True)
# Out:
# <xarray.DataArray 'mrsol' ()> Size: 8B
# -66.22
# Attributes:
#     standard_name:  mass_content_of_water_in_soil_layer
#     long_name:      Total Water Content of Soil Layer
#     units:          kg m-2
#     comment:        in each soil layer, the mass of water in all phases, incl...
#     original_name:  mrsol
#     cell_methods:   area: mean where land time: mean
#     cell_measures:  area: areacella
#     history:        2019-09-11T14:22:11Z altered by CMOR: Reordered dimension...

# %%
predictor = Play.distribution_building.distribution_predictor(var_max_run_idx=11)
Play.distribution_analise.single_residual_split_histogram_vs_mixed_distribution(predictor,min_run_idx=11, max_run_idx=40)

# %%
predictor = Play.distribution_building.distribution_predictor(var_max_run_idx=11, Transform = True)
Play.distribution_analise.single_residual_split_histogram_vs_mixed_distribution(predictor,min_run_idx=11, max_run_idx=40, Transform = True) #runs
# Out:
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# /home/pjunghans/miniconda3/envs/mesmer-tests/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:820: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# yeaay
